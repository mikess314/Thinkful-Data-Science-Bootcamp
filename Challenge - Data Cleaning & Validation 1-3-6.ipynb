# %%
import pandas as pd
import re

# %%
trust = pd.read_csv('Desktop/Desktop/Thinkful DS Bootcamp/DataCleaningChallenge/WELLCOME_APCspend2013_forThinkful.csv', encoding='iso-8859-1')

# %%
trust.head(10)
# Out:
#               PMID/PMCID                                     Publisher  \
# 0                    NaN                                           CUP
# 1             PMC3679557                                           ACS
# 2  23043264  PMC3506128                                            ACS
# 3    23438330 PMC3646402                                           ACS
# 4   23438216 PMC3601604                                            ACS
# 5             PMC3579457                                           ACS
# 6             PMC3709265                                           ACS
# 7   23057412 PMC3495574                                            ACS
# 8      PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 9      PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
#
#                     Journal title  \
# 0          Psychological Medicine
# 1               Biomacromolecules
# 2                      J Med Chem
# 3                      J Med Chem
# ...

# %% [markdown]
# ### The challenge is to:
#
# ### -Determine the five most common journals and the total articles for each.
# ### -Calculate the mean, median, and standard deviation of the open-access cost per article for each journal

# %%
trust.columns
# Out:
# Index(['PMID/PMCID', 'Publisher', 'Journal title', 'Article title',
#        'COST (£) charged to Wellcome (inc VAT when charged)'],
#       dtype='object')

# %%
trust['Journal title'] = trust['Journal title'].str.lower()
trust['Journal title'] = trust['Journal title'].str.capitalize()
trust['Journal title'] = trust['Journal title'].str.strip()

# %%
trust['Journal title'].head(40)
# Out:
# 0                           Psychological medicine
# 1                                Biomacromolecules
# 2                                       J med chem
# 3                                       J med chem
# 4                                       J org chem
# 5                   Journal of medicinal chemistry
# 6                     Journal of proteome research
# 7                                        Mol pharm
# 8                             Acs chemical biology
# 9                             Acs chemical biology
# 10    Journal of chemical information and modeling
# 11                  Journal of medicinal chemistry
# 12                  Journal of medicinal chemistry
# 13                                    Biochemistry
# 14                  Journal of medicinal chemistry
# 15                                Gastroenterology
# 16                 Journal of biological chemistry
# 17                           Journal of immunology
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
trust_grouped_title.head()
# Out:
# Journal title
# Academy of nutrition and dietetics                               2379.540
# Acs chemical biology                                             1418.186
# Acs chemical neuroscience                                        1186.800
# Acs nano                                                          668.140
# Acta crystallographica section d,  biological crystallography     771.420
# Name: Cost, dtype: float64

# %%
trust.rename(columns={'COST (£) charged to Wellcome (inc VAT when charged)': 'Cost'}, inplace=True)
trust['Cost'] = trust['Cost'].replace("£","")
trust['Cost'].head(10)
# Out:
# 0       £0.00
# 1    £2381.04
# 2     £642.56
# 3     £669.64
# 4     £685.88
# 5    £2392.20
# 6    £2367.95
# 7     £649.33
# 8    £1294.59
# 9    £1294.78
# Name: Cost, dtype: object

# %%
trust['Cost'] = trust['Cost'].str.replace("£", "")
trust['Cost'].head(10)
#adding .str to .replace fixed the issue
# Out:
# 0       0.00
# 1    2381.04
# 2     642.56
# 3     669.64
# 4     685.88
# 5    2392.20
# 6    2367.95
# 7     649.33
# 8    1294.59
# 9    1294.78
# Name: Cost, dtype: object

# %%
trust['Cost'] = trust['Cost'].str.replace("$", "")
trust['Cost'].head(10)
# Out:
# 0       0.00
# 1    2381.04
# 2     642.56
# 3     669.64
# 4     685.88
# 5    2392.20
# 6    2367.95
# 7     649.33
# 8    1294.59
# 9    1294.78
# Name: Cost, dtype: object

# %%
trust['Cost'] = pd.to_numeric(trust['Cost'])

# %%
trust = trust[trust.Cost <= 6000 ]

# %%
trust = trust[trust.Cost > 0 ]

# %%
trust.head()
# Out:
#               PMID/PMCID Publisher                   Journal title  \
# 1             PMC3679557       ACS               Biomacromolecules
# 2  23043264  PMC3506128        ACS                      J med chem
# 3    23438330 PMC3646402       ACS                      J med chem
# 4   23438216 PMC3601604        ACS                      J org chem
# 5             PMC3579457       ACS  Journal of medicinal chemistry
#
#                                        Article title     Cost
# 1  Structural characterization of a Model Gram-ne...  2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   669.64
# 4  Regioselective opening of myo-inositol orthoes...   685.88
# 5  Comparative Structural and Functional Studies ...  2392.20

# %%
trust['Cost'].describe()
# Out:
# count    2076.000000
# mean     1822.933584
# std       766.840519
# min         9.930000
# 25%      1268.700000
# 50%      1851.650000
# 75%      2302.330000
# max      6000.000000
# Name: Cost, dtype: float64

# %%
trust_grouped_title = trust.groupby(['Journal title'])['Cost'].mean()

# %%
trust.groupby(['Journal title']).count().sort_values('Cost', ascending=False)
# Out:
#                                                     PMID/PMCID  Publisher  \
# Journal title
# Plos one                                                   180        182
# Journal of biological chemistry                             51         52
# Neuroimage                                                  28         29
# Nucleic acids research                                      25         26
# Proceedings of the national academy of sciences             22         22
# Plos pathogens                                              22         22
# Plos genetics                                               22         22
# Plos neglected tropical diseases                            20         20
# Nature communications                                       18         18
# Human molecular genetics                                    16         18
# Brain                                                       11         14
# ...

# %% [markdown]
# ### Most common Journal Titles with numbers of articles
# 1. Plos one - 182
# 2. Journal of biological chemistry - 52
# 3. Neuroimage - 29
# 4. Nucleic acids research - 26
#
# ### Three tied for 5th:
# Proceedings of the national academy of sciences	- 22
# Plos pathogens	- 22
# Plos genetics	- 22

# %%
trust['Cost'].describe()
# Out:
# count    2076.000000
# mean     1822.933584
# std       766.840519
# min         9.930000
# 25%      1268.700000
# 50%      1851.650000
# 75%      2302.330000
# max      6000.000000
# Name: Cost, dtype: float64

# %% [markdown]
# ### Calculate the mean, median, and standard deviation of the open-access cost per article for each journal
#
# Changed the column name to Cost and the summary statistics are all above.
